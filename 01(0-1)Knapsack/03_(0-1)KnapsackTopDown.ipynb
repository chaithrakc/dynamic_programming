# %% [markdown]
# ### 0-1 Knapsack Problem using dynamic programming:
#
# Since subproblems are evaluated again, this problem has Overlapping Sub-problems property. So the 0-1 Knapsack problem has both properties (Overlapping Subproblems and Optimal Substructure) of a dynamic programming problem. Like other typical Dynamic Programming(DP) problems, re-computation of the same subproblems can be avoided by constructing a temporary array `t[][]` in a top-down manner.

# %%
t = [[]]
